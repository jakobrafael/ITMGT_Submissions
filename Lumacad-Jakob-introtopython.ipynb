# %% [markdown]
# 172640
# Lumacad
# 4 BS CTM

# %%
# choose your 3 numbers
num1 = float(input('First number: '))
num2 = float(input('Second number: '))
num3 = float(input('Third number: '))

#the formula to get the average of your 3 inputted numbers
avg = (num1 + num2 + num3)/3

#
print('The average of your 3 numbers are = %0.2f' %avg)
# Out:
# First number:  2
# Second number:  3
# Third number:  4
# The average of your 3 numbers are = 3.00
