# %% [markdown]
# Lumacad
# 172640
# 4 BS CTM

# %% [markdown]
# Problem 1

# %%
dollars = int(input('Input amount in US Dollars: '))
pesos = 50*dollars
print('Your conversion from USD to Php = %0.0f' %pesos)
# Out:
# Input amount in US Dollars:  100
# Your conversion from USD to Php = 5000

# %% [markdown]
# Problem 2

# %%
a = int(input('First positive integer'))
b = int(input('Second positive integer'))

sum = a + b
subtract = a - b
product = a*b
quotient = a/b
remainder = a % b

print(sum)
print(subtract)
print(product)
print(quotient)
print(remainder)
# Out:
# First positive integer 1
# Second positive integer 2
# 3
# -1
# 2
# 0.5
# 1

# %% [markdown]
# Problem 3

# %%
kg = float(input('Your weight:'))
cm = float(input('Your height:'))
m = cm/100

bmi = kg/(m*m)
print("Your body mass index is %f" %bmi)
# Out:
# Your weight: 7
# Your height: 180000
# Your body mass index is 0.000002
